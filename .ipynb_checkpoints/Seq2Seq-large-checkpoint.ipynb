# %% [markdown]
# # 1 Processing

# %%
import  pandas as pd
import logging
import glob
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 500)
logger = logging.getLogger()
logger.setLevel(logging.WARNING)

# %%
# Split training and test
data = pd.read_csv('consumer_complaints.csv')
pData = data.dropna(subset=["Consumer complaint narrative", "Issue", "Sub-issue"])
traindf, testdf = train_test_split(pData, 
                                   test_size=.10)
# print data sizes
print(f'Train: {traindf.shape[0]:,} rows {traindf.shape[1]:,} columns')
print(f'Test: {testdf.shape[0]:,} rows {testdf.shape[1]:,} columns')
traindf.head(3)
# Out:
# Train: 200,970 rows 18 columns
# Test: 22,331 rows 18 columns
#         Date received          Product               Sub-product  \
# 1050036    08/08/2016  Debt collection                   Medical
# 1081960    12/29/2015     Student loan  Non-federal student loan
# 1074571    03/16/2018     Student loan      Private student loan
#
#                                          Issue  \
# 1050036  Cont'd attempts collect debt not owed
# 1081960     Dealing with my lender or servicer
# 1074571   Dealing with your lender or servicer
#
#                                                       Sub-issue  \
# 1050036                                        Debt is not mine
# 1081960                   Trouble with how payments are handled
# 1074571  Need information about your loan balance or loan terms
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Consumer complaint narrative  \
# 1050036                                                                                                                                                                                                                                                                                                              Provided no proof of debt during disputes and I have continuously disputed the debt with a credit reporting agency without any information on what the debt is from being provided by the organization.
# 1081960  My Private Wells Fargo loan is literally theft. I have been unable to have a balance budget with a {$250.00} monthly payment along with all my other debts, bills, and living expenses. My city 's living expenses are going up, making it difficult on a bi-weekly basis to have money to eat. Also, making difficult to save money to pursue my passion of music, as it was reason for me to pursue a college degree and required this loan. Spoke with the Loans Consolidation department and the Loan Modifi...
# 1074571  I admit that I owe something but the loan amount itself should not be more than {$10000.00} then whatever interest it would have accrued over time. \n\nAlso, the student loan company has taken my tax refund on a couple of occasions. One time it was nearly {$8000.00} The contracts they sent me if they are legitimate amount to less than {$10000.00}, nowhere near the {$30000.00} they say I owe. \n\nKeep in mind ACT student loans must have sold the rights to consolidate and take over my student ...
#
#                                   Company public response  \
# 1050036                                               NaN
# 1081960  Company chooses not to provide a public response
# 1074571                                               NaN
#
#                          Company State ZIP code           Tags  \
# 1050036                 Io, Inc.    VA      NaN  Servicemember
# 1081960    WELLS FARGO & COMPANY    TX    787XX            NaN
# 1074571  Navient Solutions, LLC.    MS      NaN  Servicemember
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 1050036           Consent provided           Web           08/08/2016
# 1081960           Consent provided           Web           12/29/2015
# 1074571           Consent provided           Web           03/16/2018
#
#         Company response to consumer Timely response? Consumer disputed?  \
# 1050036                       Closed              Yes                 No
# 1081960      Closed with explanation              Yes                 No
# 1074571      Closed with explanation              Yes                NaN
#
#          Complaint ID
# 1050036       2050841
# 1081960       1719881
# 1074571       2845553

# %%
trainRawNarrative = traindf['Consumer complaint narrative'].tolist()
trainIssueRaw = traindf['Issue']

# %%
# %reload_ext autoreload
# %autoreload 2
from ktext.preprocess import processor
# Out:
# C:\Users\gstot\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# %%time
# Clean, tokenize, and apply padding / truncating such that each document length = 70
#  also, retain only the top 8,000 words in the vocabulary and set the remaining words
#  to 1 which will become common index for rare words 
body_pp = processor(keep_n=8000, padding_maxlen=144)
train_body_vecs = body_pp.fit_transform(trainRawNarrative)
# Out:
# WARNING:root:....tokenizing data
# WARNING:root:(1/2) done. 140 sec
# WARNING:root:....building corpus
# WARNING:root:(2/2) done. 14 sec
# WARNING:root:Finished parsing 200,970 documents.
# WARNING:root:...fit is finished, beginning transform
# WARNING:root:...padding data
# WARNING:root:done. 10 sec
# Wall time: 2min 46s

# %%
issue_pp = processor(append_indicators=True, keep_n=4500, 
                     padding_maxlen=12, padding ='post')

# process the title data
train_issue_vecs = issue_pp.fit_transform(trainIssueRaw)
# Out:
# WARNING:root:....tokenizing data
# WARNING:root:(1/2) done. 12 sec
# WARNING:root:....building corpus
# WARNING:root:(2/2) done. 0 sec
# WARNING:root:Finished parsing 200,970 documents.
# WARNING:root:...fit is finished, beginning transform
# WARNING:root:...padding data
# WARNING:root:done. 1 sec

# %%
import dill as dpickle
import numpy as np

# Save the preprocessor
with open('body_pp.dpkl', 'wb') as f:
    dpickle.dump(body_pp, f)

with open('issue_pp.dpkl', 'wb') as f:
    dpickle.dump(issue_pp, f)

# Save the processed data
np.save('train_issue_vecs.npy', train_issue_vecs)
np.save('train_body_vecs.npy', train_body_vecs)

# %%
from seq2seq_utils import load_decoder_inputs, load_encoder_inputs, load_text_processor

# %%
encoder_input_data, doc_length = load_encoder_inputs('train_body_vecs.npy')
decoder_input_data, decoder_target_data = load_decoder_inputs('train_issue_vecs.npy')
# Out:
# Shape of encoder input: (200970, 144)
# Shape of decoder input: (200970, 11)
# Shape of decoder target: (200970, 11)

# %%
num_encoder_tokens, body_pp = load_text_processor('body_pp.dpkl')
num_decoder_tokens, title_pp = load_text_processor('issue_pp.dpkl')
# Out:
# Size of vocabulary for body_pp.dpkl: 8,002
# Size of vocabulary for issue_pp.dpkl: 115

# %%
# %matplotlib inline
from keras.models import Model
from keras.layers import Input, LSTM, GRU, Dense, Embedding, Bidirectional, BatchNormalization
from keras import optimizers

# %%
#arbitrarly set latent dimension for embedding and hidden units
latent_dim = 300

##### Define Model Architecture ######

########################
#### Encoder Model ####
encoder_inputs = Input(shape=(doc_length,), name='Encoder-Input')

# Word embeding for encoder (ex: Issue Body)
x = Embedding(num_encoder_tokens, latent_dim, name='Body-Word-Embedding', mask_zero=False)(encoder_inputs)
x = BatchNormalization(name='Encoder-Batchnorm-1')(x)

# Intermediate GRU layer (optional)
#x = GRU(latent_dim, name='Encoder-Intermediate-GRU', return_sequences=True)(x)
#x = BatchNormalization(name='Encoder-Batchnorm-2')(x)

# We do not need the `encoder_output` just the hidden state.
_, state_h = GRU(latent_dim, return_state=True, name='Encoder-Last-GRU')(x)

# Encapsulate the encoder as a separate entity so we can just 
#  encode without decoding if we want to.
encoder_model = Model(inputs=encoder_inputs, outputs=state_h, name='Encoder-Model')

seq2seq_encoder_out = encoder_model(encoder_inputs)

########################
#### Decoder Model ####
decoder_inputs = Input(shape=(None,), name='Decoder-Input')  # for teacher forcing

# Word Embedding For Decoder (ex: Issue Titles)
dec_emb = Embedding(num_decoder_tokens, latent_dim, name='Decoder-Word-Embedding', mask_zero=False)(decoder_inputs)
dec_bn = BatchNormalization(name='Decoder-Batchnorm-1')(dec_emb)

# Set up the decoder, using `decoder_state_input` as initial state.
decoder_gru = GRU(latent_dim, return_state=True, return_sequences=True, name='Decoder-GRU')
decoder_gru_output, _ = decoder_gru(dec_bn, initial_state=seq2seq_encoder_out)
x = BatchNormalization(name='Decoder-Batchnorm-2')(decoder_gru_output)

# Dense layer for prediction
decoder_dense = Dense(num_decoder_tokens, activation='softmax', name='Final-Output-Dense')
decoder_outputs = decoder_dense(x)

########################
#### Seq2Seq Model ####

#seq2seq_decoder_out = decoder_model([decoder_inputs, seq2seq_encoder_out])
seq2seq_Model = Model([encoder_inputs, decoder_inputs], decoder_outputs)


seq2seq_Model.compile(optimizer=optimizers.Nadam(lr=0.001), loss='sparse_categorical_crossentropy')

# %%
from seq2seq_utils import viz_model_architecture
seq2seq_Model.summary()
#viz_model_architecture(seq2seq_Model)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Decoder-Input (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# Decoder-Word-Embedding (Embeddi (None, None, 300)    34500       Decoder-Input[0][0]
# __________________________________________________________________________________________________
# Encoder-Input (InputLayer)      (None, 144)          0
# __________________________________________________________________________________________________
# Decoder-Batchnorm-1 (BatchNorma (None, None, 300)    1200        Decoder-Word-Embedding[0][0]
# __________________________________________________________________________________________________
# Encoder-Model (Model)           (None, 300)          2942700     Encoder-Input[0][0]
# __________________________________________________________________________________________________
# Decoder-GRU (GRU)               [(None, None, 300),  540900      Decoder-Batchnorm-1[0][0]
#                                                                  Encoder-Model[1][0]
# __________________________________________________________________________________________________
# Decoder-Batchnorm-2 (BatchNorma (None, None, 300)    1200        Decoder-GRU[0][0]
# __________________________________________________________________________________________________
# Final-Output-Dense (Dense)      (None, None, 115)    34615       Decoder-Batchnorm-2[0][0]
# ==================================================================================================
# Total params: 3,555,115
# Trainable params: 3,553,315
# Non-trainable params: 1,800
# __________________________________________________________________________________________________

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint

script_name_base = 'tutorial_seq2seq'
csv_logger = CSVLogger('{:}.log'.format(script_name_base))
model_checkpoint = ModelCheckpoint('{:}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5'.format(script_name_base),
                                   save_best_only=True)

batch_size = 1200
epochs = 7
history = seq2seq_Model.fit([encoder_input_data, decoder_input_data], np.expand_dims(decoder_target_data, -1),
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.12, callbacks=[csv_logger, model_checkpoint])
# Out:
# Train on 176853 samples, validate on 24117 samples
# Epoch 1/7
# 176853/176853 [==============================] - ETA: 29:02 - loss: 5.70 - ETA: 26:03 - loss: 4.42 - ETA: 24:54 - loss: 3.65 - ETA: 24:15 - loss: 3.11 - ETA: 23:46 - loss: 2.73 - ETA: 23:26 - loss: 2.44 - ETA: 23:09 - loss: 2.21 - ETA: 22:53 - loss: 2.02 - ETA: 22:39 - loss: 1.86 - ETA: 22:24 - loss: 1.73 
#  Written notification about debt
#
# ****** Machine Generated Title (Prediction) ******:
#  disclosure verification of debt
#
#
# ==============================================
# ============== Example # 21837 =================
#
# 2327414
# Issue Body:
#  My consolidated PLUS loans are now serviced by NAVIENT. I am in the IBR program and make a {$420.00} payment every month. Due to the high interest rate on this loan, there is no possible way I can ever pay any of the principal balance on this loan and no possible way I can ever pay down this debt. In XXXX they capitalized over {$3500.00} in interest. How will I ever get out from under this debt if the interest keeps increasing my Principal balance ... I am so frustrated with this unfair and unrealistic position.
#
# Original Title:
#  Can't repay my loan
#
# ****** Machine Generated Title (Prediction) ******:
#  dealing with my lender or servicer
#
#
# ==============================================
# ============== Example # 21330 =================
#
# 2798248
# Issue Body:
#  I opened an account with Home Depot. They never sent me a bill and have been charging me late fees. I have spoken and written to them about the problem and told them that I would gladly pay the bill when receive a bill. The continue to hassel me and add charges. They have called multiple times and have not corrected the problem. I refuse to pay any late fees they have added due to their mistake. They have been completely unresponsive.
#
# Original Title:
#  Problem when making payments
#
# ****** Machine Generated Title (Prediction) ******:
#  fees or interest
#
#
# ==============================================
# ============== Example # 4269 =================
#
# 2234462
# Issue Body:
#  I followed Experian 's online protocol to correct addresses. I received their response and the information was still incorrect. When I again followed protocol to correct, the options provided on the website do not allow for additional options. The only options from a dropdown menu are : Never lived there Belongs to another person with same or similar name Identity theft I just need these XXXX addresses deleted as they are incorrect. The correct address is already correctly listed in my report. These are the XXXX that need to be deleted : Address : XXXX XXXX XXXX XXXX XXXX ( This should read XXXX, but as stated above, it is already correctly included in the report. ) XXXX XXXX, XXXX XXXX Address identification number : XXXX Type of Residence : Apartment complex Geographical code : XXXX Address : XXXX XXXX XXXX XXXX # XXXX ( This address is incomplete, and again, the correct address is already included in the report. ) XXXX XXXX, XXXX XXXX Address identification number : XXXX Type of Residence : Apartment complex Geographical code : XXXX I HAVE NEVER LIVED AT THE BELOW ADDRESS and after using the drop down option of " Never lived there before, '' the following message I received was to contact the creditor who provided this information. I do not know who the creditor is.
# Address : XXXX XXXX XXXX XXXX, XXXX XXXX Address identification number : XXXX Type of Residence : Single family Geographical code : XXXX
#
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on credit report
#
#
# ==============================================
# ============== Example # 4396 =================
#
# 2689667
# Issue Body:
#  I have a collection account on my three ( 3 ) credit files from a collection agency named Trident Asset Management, LLC.  Please be advised that I am disputing this collection due to the fact Trident Asset Management, LLC, XXXX XXXX XXXX XXXX, XXXX XXXX, XXXX, GA XXXX XXXX XXXX. XXXX XXXX, XXXX, GA XXXX ) does not have a valid license nor a certificate of authority in Mississippi to collect on debts. This information is stating that their license is currently nonexistent according to https : XXXX. Furthermore, this company never contacted me about this account but just placed the account on my credit reports without verifying if the information is true or if the item is mine or not. In reference to the Fair Credit Reporting Act, Section 609 ( a ) ( 1 ) ( A ), validation letters were sent to XXXX,  XXXX, and XXXX on XXXX XXXX, XXXX. The account was deleted from XXXX ; however, no proof was provided to me by XXXX nor XXXX as of the date of this letter and it continues to remain on both reports.
#
# Original Title:
#  Problem with a credit reporting company's investigation into an existing problem
#
# ****** Machine Generated Title (Prediction) ******:
#  attempts to collect debt not owed
#
#
# ==============================================
# ============== Example # 22316 =================
#
# 2204725
# Issue Body:
#  There are multi accounts that do n't belong to me, I have contacted the them directly and they were very rude, I have disputed them with all XXXX credit reporting agencies and nothing is fixed. I do n't feel it is fair that I pay an attorney to get this corrected.
#
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on credit report
#
#
# ==============================================
# ============== Example # 7848 =================
#
# 1543789
# Issue Body:
#  his is just an ongoing event with Experian concerning the removal of address 's that I have stated many times via this portal, certified mail or even fax. I have submitted my utility bill, Drivers License, social security card, Police Report and now I am being requested once again from Experian to submit a statement that the address 's do n't belong to me, a police report and now they have added a FTC affidavit which I have attached to this portal along with everything else. I have been disputing this information since XXXX/XXXX/15 and they have outright refused to removed all of the disputed information especially with the mountain load of supporting documentation that I have sent them. I have received letter after letter stating we will have to have the furnisher verify this information first before we can remove it. Your furnisher is the reason why the information is reported incorrectly and I have submitted many documents showing your Reporting agency that it is wrong and to make it right. I am the victim of Identity theft that is why I put a fraud alert on all my credit reports and reported this to the XXXX Police station. By Law Experian your suppose to block and or delete the fraudulent information from my credit file within four days but as of today 2 months since I first disputed ou have done nothing but verify that those address ; s must stay due to your furnisher verifying the address 's and the wrong variations of my name. Your all wrong and I want the items corrected immediately. Here is the information that I am disputing once again : XXXX XXXX, XXXX XXXX XXXX XXXX, XXXX XXXXExperian, XXXX XXXX XXXX, XXXX XXXX : Consumer Dispute Dept.
#
# RE : Report # XXXXTo Whom It May Concern : THIS IS a request to have invalid address 's and different variations pf my name deleted from my consumer file. I request Experian to remove inaccurate information that they and or the Banks that they service has put on my consumer report. These following addresses I am here and now disputing as addresses that I AM NOT associated with and I DO NOT LIVE AT NOR HAVE I EVER LIVED XXXX XXXX XXXX XXXX XXXX XXXX, XXXX XXXX XXXX XXXX XXXX XXXX XXXX XXXX , XXXX XXXX XXXX XXXX XXXX , XXXX XXXX ( WHICH IS MY EX-HUSBAND 'S RESIDENCE NOT MINE ) XXXX XXXX XXXX , XXXX XXXX XXXX XXXX XXXX, XXXX XXXX XXXX XXXX XXXX , XXXX XXXX XXXX XXXX XXXX , XXXX XXXX ( THIS IS MY PARENT 'S HOME NOT MINE PLEASE DELETE ) XXXX XXXX XXXX XXXX , XXXX XXXX XXXX XXXX, XXXX XXXX AGAIN ASK YOU TO DELETE TO DRIVERS LICENSE INFORMATION ON MY CONSUMER REPORT : DRIVERS LICENSE NUMBER : XXXXSTATE OF ISSUANCE : XXXXFINANCIAL INSTITUTIONS : XXXX XXXX XXXX XXXX XXXXI have also attached the police Report that I have filed here is XXXX, XXXX I have filed for ID Theft protection because there is no way I can leave in XXXX different states a one time and then XXXX different cities and all these different address. Please remove this address 's and the financial institutions that are connected to them because these are not mine it is fraud.
#
#
# Thank you, XXXX XXXX
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on credit report
#
#
# ==============================================
# ============== Example # 10203 =================
#
# 2345105
# Issue Body:
#  Good Afternoon, I am a US military service member, and a responsible citizen with a clean and well standing credit record.
# I was contacted by " FIRST FINANCIAL ASSET MANAGEMENT '' ( XXXX ) a Debt Collection agency. They contacted me to collect on a Fraudulent account, that was opened in my name in 2005, they threatened to blemish my credit profile and even attempted to " SETTLE '' the account. they have illegally purchased my personal information and identity from another debt collector or illegitimate source.
#
# Original Title:
#  Cont'd attempts collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 5634 =================
#
# 2510753
# Issue Body:
#  XXXX   XXXX   XXXX  posted a check for {$1800.00} to  Ally  Bank last week via express mail and it has still not been received by the Bank.
# The 1st check was returned and   I need this matter resolved.
#
# Original Title:
#  Managing an account
#
# ****** Machine Generated Title (Prediction) ******:
#  managing an account
#
#
# ==============================================
# ============== Example # 335 =================
#
# 1725627
# Issue Body:
#  It 's BB & T calling every morning at XXXX in an attempt to collect a debt for a charged off account. This phone number does not belong to the person owing the debt, but does belong to a relative of the person. It 's annoying because its not a live person but a recorded message. Please stop these calls
#
# Original Title:
#  Communication tactics
#
# ****** Machine Generated Title (Prediction) ******:
#  communication tactics
#
#
# ==============================================
# ============== Example # 15799 =================
#
# 2708151
# Issue Body:
#  Submitted dispute to Equifax regarding an incorrect address on my credit report.
#
# I received an email that the dispute was resolved on XX/XX/XXXX, 2017. HOWEVER, when I tried to login to the Equifax website to see the status of the dispute and what now shows on my report, I was denied access due to " inaccurate '' information to verify my identity and they asked me a ton of questions verifying my identity and I do n't even feel comfortable giving them all this considering they just lost a TON of my data and others.
# I ALSO tried calling and was repeatedly hung up on before I could ever get to a representative.
# I want my credit information to be accurate and I saw this address on a different report which was successfully corrected. I do n't want my identity stolen.
#
# Original Title:
#  Problem with a credit reporting company's investigation into an existing problem
#
# ****** Machine Generated Title (Prediction) ******:
#  problem with a credit reporting company s investigation into an existing issue
#
#
# ==============================================
# ============== Example # 5365 =================
#
# 1619700
# Issue Body:
#  I have several hard pulls on my report that are not mine. for months I have been trying to work with eqifax and have even disputed the pulls. the dispute was entered at night and not 8 hours later they stated they investigated it and they were not pulling the wrong info down. I also disputed the info with experian and XXXX whom took my report and took the wrongful hard pulls down, started a fraud alert and were very helpful. Equifax is near impossible to get anyone that can or will do anything, today I filed a police report due to hard pulls that are not mine, Equifax stated they would not do anything about it. I 'm submitting complaint here in hopes to get action.
#
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  credit reporting company s investigation
#
#
# ==============================================
# ============== Example # 1174 =================
#
# 2479896
# Issue Body:
#  I o  btained my Transunion credit report on line. There were U. S. Bankruptcy Court items listed on my credit reports. Per the FCRA 623 ( a ) ( 5 ) : If the Credit Bureau can not VALIDATE the information with the ORIGINAL CREDITOR, they must remove said information from the consumer credit file.
# The County Recorder of Deeds and the Bankruptcy Courts have also reviewed the Public Record section youre your Transunion Credit Bureau. They both mailed me letters which emphatically stated that they do NOT provide any information to credit reporting agencies, nor do they ever validate and/or confirm public records. It is the credit reporting agencies, and/or other third party providers who collect information regarding public cases from public records. Public records information is NEVER validated by the Recorder of Deeds nor the U. S. Court system due to the Fair Credit Reporting Agency PRIVACY LAW.
# My inquiry to the County Recorder of Deeds and U. S. Bankruptcy Courts confirmed Transunion Credit Bureau has never validated or verified these public record entries on my credit report, neither will they ever be by them. They further stated while they are NOT liable or responsible for any MISUSE or INCORRECT public records, nor the distribution of said information, public records may, and oftentimes are, reported by third party sources unawares to the consumer, and in most cases, incorrectly. Considering the information indicating a Fair Credit Reporting Act violation, I need all tax lien and bankruptcy information currently showing under my social security number to be PERMANENTLY DELETED from my credit report immediately.
# The Transunion Credit Bureau needs to provide me with copies of all documentation associated with these Public Record Accounts bearing either a court order to place this information in my credit report, or my authorization of release bearing my signature. In the meantime, to be in full compliance with the FCRA laws and guidelines, all the information listed under Public Records needs to be immediately deleted from the credit file you maintain under my name and social security number. Be further advised that I am closely monitoring my credit file. Per the Federal Law, you have exactly 30 days to complete this investigation as outlined per the Fair Credit Reporting Act 623 ( a ) ( 3 ).       See document attached from the courts.     Transunion File #  XXXX   XXXX   XXXX   XXXX  Little  XXXX   XXXX   XXXX , GA  XXXX
#
# Original Title:
#  Incorrect information on your report
#
# ****** Machine Generated Title (Prediction) ******:
#  improper use of my credit report
#
#
# ==============================================
# ============== Example # 12128 =================
#
# 2764773
# Issue Body:
#  Pursuant of the FCRA, I demanded a detailed explanation of the procedures used to validate accounts being reported by XXXX XXXX XXXX subsidiaries XXXX XXXX and XXXX within 15 days. My request was made on XX/XX/2017. 18 days have elapsed and I still do not have an explanation of how they validated the account. The reason I am asking for an explanation is, I have made numerous attempts to verify this information directly with the company and they have always failed to provide any evidence that I actually owe them anything. I would like an opportunity to review any documentation available from the creditors to determine if this debt is valid.
#
# Original Title:
#  Problem with a credit reporting company's investigation into an existing problem
#
# ****** Machine Generated Title (Prediction) ******:
#  problem with a credit reporting company s investigation into an existing issue
#
#
# ==============================================
# ============== Example # 12808 =================
#
# 2820931
# Issue Body:
#  Affidavit of Demand XXXX XXXX XXXX COMMONWEALTH OF PENNSYLVANIA XXXX COUNTY OF UNITED STATES The undersigned, XXXX XXXX XXXX, being duly sworn, hereby deposes and says : 1. I am over the age of 18 and am a resident of the Commonwealth of Pennsylvania. I have personal knowledge of the facts herein, and, if called as a witness, could testify completely thereto. 2. I suffer no legal disabilities and have personal knowledge of the facts set forth below. 3. Date : XX/XX/2018 Dear Innovis FTC Report Number : XXXX Victim Fraud Assistance Department, I have included all pages with the official police report from the XXXX Police Department. Also, you have a notarized FTC Federal Identity Theft Victim 's Complaint and Affidavit. Under FCRA 605B ( 15 U.S.C. 1681c-2 ) you are to block any information in the file of a consumer that the consumer identified as information that resulted from an alleged identity theft, not later than 4 business days after the date of receipt. I sent you clear legible copies of my credit report, FTC Identity Theft report, Official copy of the Identity Theft Police Report signed and notarized. I previously notified you in recent certified letters and affidavits that I am a victim of identity theft, and requested that you do the following : Close the unauthorized accounts and credit inquires Remove any charges on the unauthorized account, and Take steps to remove information about this account from my credit files I still have not received written confirmation of these actions. As I stated before : I am a victim of identity theft. I recently learned that my personal information was used fraudulently. I did not open or authorize these accounts and inquiries, and I request that it be closed immediately. I have enclosed a copy of my FTC Identity Theft Report. Because the information you are reporting is the result of identity theft, and inaccurate, I request that you stop reporting this information to XXXX, as directed by section 623 ( a ) ( 1 ) ( B ) of the Fair Credit Reporting Act, 15 U.S.C. 1681s-2 ( a ) ( 1 ) ( B ). I ask that you take these steps as soon as possible. I also have enclosed a copy of the F.T.C 's Identity Theft Affidavit, which explains your responsibilities when reporting information to Innovis. Please stop reporting this fraudulent information and delete any fraudulent items as soon as possible. If you do not otherwise block my consumer information on my credit reports I will be left with no choice but to file a lawsuit that you volatile the F.C.R.A 605B law and how Its affecting my ability to work and buy a home. Sincerely, XXXX XXXX XXXX cc : Pennsylvania Attorney General Office cc : XXXX XXXX XXXX cc : Consumer Financial Protection Bureau cc : Office of United States Senator XXXX XXXX cc : PA Banking and Securities
# Original Title:
#  Incorrect information on your report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on your report
#
#
# ==============================================
# ============== Example # 12528 =================
#
# 2669332
# Issue Body:
#  ON XXXX PHEAA/AES determined they made a mistake and the loans they have are in fact not mine. SEE attached transcript of live chat conversation with AES XXXX, and screenshot of them confirming they were not my original lenders.
# I have told them I paid my loans off years ago. AES/PHEAA confirmed they were not my original loan lenders, and never had my loans. But they refuse to : 1 ) return my payments/money they collected XX/XX/XXXX-XX/XX/XXXX 2 ). NOTIFY Direct Loans/USDEPT OF ED default resolution/immed cr. recovery collection agency that these are not my loans so they can return my {$8000.00} they seized from me.
# 3. ) REFUSE TO NOTIFY/UPDATE NEGAATIVE credit reporting on me.
# 4 ) REFUSE TO remove my name off these loans.
# 5 ) UPDATE NSLD WEBSITE I am a female XXXX XXXX vet, and they have my money, and continue to cause me extreme unnecessary financial hardship by refusing to do their jobs, and get my name off these loans they know are not mine, notify the lender they sold the loans to, return my money, or update my credit report. knowing all this.
#
# please help me.
# XXXX XXXX
#
# Original Title:
#  Dealing with your lender or servicer
#
# ****** Machine Generated Title (Prediction) ******:
#  dealing with your lender or servicer
#
#
# ==============================================
# ============== Example # 8246 =================
#
# 1769367
# Issue Body:
#  I wrote a check # XXXX to XXXX XXXX for {$20.00} in XXXX, Ca. They ran the check electronically ( Telecheck ) to get their money right then, but did not give me back the check. XXXX XXXX deposited the check through their bank. They got paid XXXX times. My bank reversed payment on the first electronically made payment. Now the check service has forwarded the debt to TRS Recovery Services, Inc for collection. TRS Recovery Services would like us to pay them for this again. They have called XXXX times before XXXX XXXX. My wife has talked to three different people at TRS about this and they still ca n't get it right. I have talked to XXXX XXXX, they said they would call ( Telecheck ) and take care of it. They have not done this at this time. Now this is going on my record that I wrote a bad check. Guess what? I 'm not buying from XXXX again!
# What can you do about this?? I have all the paper work from the Bank. I have forwarded this to the TRS Recovery Services. Fax # XXXX Can you give me any help on this?
# Thank you!!
#
# Original Title:
#  Cont'd attempts collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  false statements or representation
#
#
# ==============================================
# ============== Example # 3314 =================
#
# 2667077
# Issue Body:
#  Equifax mishandled my information which has led to a breach that puts myself and millions of others at potential risk. I am extremely disappointed with how equifax has handled reporting this breach. Very little was done to notify the public for nearly a month after the breach was detected. I received no email, letter, or phone call and instead had to discover it via social media.
#
# Going forward equifax should be required to monitor every account and notify victims if any fraud occurs. Credit fraud protection should be mandatory for every account, not an option for us to have deal with. I 've already spent money purchasing additional Credit Monitoring services as well as Identity Protection services.
#
# This should be rectified firstly by making credit freezing free and refunding everyone who paid for it following this data breach. Requiring a police report is absurd when they clearly know if you were affected.
#
# Original Title:
#  Improper use of your report
#
# ****** Machine Generated Title (Prediction) ******:
#  improper use of your report
#
#
# ==============================================
# ============== Example # 2169 =================
#
# 1895128
# Issue Body:
#  I had worked with XXXX and XXXX XXXX from Delta Management Associates who were handling collections on behalf of American Student Assistance regarding defaulted Federal Stafford Loans. I had provided a payment of {$7800.00} to be applied to loan XXXX which would be paid off in full. The XXXX remaining loans of XXXX, XXXX, XXXX would be entered into rehabilitation with a monthly payment of {$230.00}. The loan ending XXXX had an interest rate of 6.8 % while the other XXXX had interest rates of 2.32 %. Delta Management Associates misappropriated my payment across all XXXX loans instead of applying payment as agreed upon and paying XXXX completely off. I view this misappropriation as a deliberate action of the loan servicing company, Delta Management Associates, and believe that their practices should not be tolerated by the US Government or the CFPB and that their license to service Student Loans should be revoked.
#
# Original Title:
#  Dealing with my lender or servicer
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 6323 =================
#
# 2404685
# Issue Body:
#  I am XXXX XXXX XXXX and do not have any debts. My cell phone number is XXXX, which I have had for 10 years. I get lots of calls from XXXX asking to speak to XXXX and saying my cell phone number is hers. On XXXX XXXX, 2017, I told them I was not XXXX, but they keep calling. They have called at least 7 more times. I am very busy at school and do not appreciate these harassing calls.
#
# Original Title:
#  Cont'd attempts collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 13452 =================
#
# 2919732
# Issue Body:
#  CRA violation no knowledge of the fraudulent accounts on my Transunion credit report. FTC ID Theft Report # XXXX
#
# Original Title:
#  Attempts to collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  attempts to collect debt not owed
#
#
# ==============================================
# ============== Example # 19373 =================
#
# 2757439
# Issue Body:
#  There are various Inquires showing on my three credit reports that I have not apply for credit at. I contacted the companies with written letters asking that they be remove due to possible fraud. I have received no positive results. I then contacted the three credit agencies with two attempts to have them removed without positive results.
#
# Original Title:
#  Incorrect information on your report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on your report
#
#
# ==============================================
# ============== Example # 16565 =================
#
# 2712297
# Issue Body:
#  To Whom It May Concern : I have noticed that you have placed an inquiry on my XXXX credit file dated XXXX/XXXX/2017. As you probably know, Credit Reporting Agencies treat inquiries as a statement of fact and will not allow a consumer to dispute them. Since it is against federal law ( Fair Credit Reporting Act15 USC 1681n ( a ) ( 1 ) ( B ) for an entity to view a customers credit report without a permissible purpose, I am writing to inquire as to your alleged purpose for doing so since I did not apply or request credit from your organization. Based on the evidence in my possession, this inquiry was performed under false pretenses as described in the clear language of the law. 15 USC 1681n ( a ) ( 1 ) ( B ) states, in part, in the case of liability of a natural person for obtaining a consumer report under false pretenses or knowingly without a permissible purpose, actual damages sustained by the consumer as a result of the failure or {$1000.00}, whichever is greater.This is informing you that this was a fraudulent application and I did not authorize your company to pull my report. I do hope that we can settle this matter amicably. Please remove this hard inquiry from my credit report upon receipt of this complaint to avoid further damage to my credit. Your immediate attention is appreciated in regards to this matter
# Original Title:
#  Improper use of your report
#
# ****** Machine Generated Title (Prediction) ******:
#  improper use of your report
#
#
# ==============================================
# ============== Example # 19955 =================
#
# 2783825
# Issue Body:
#  I am enrolled in the Public Service Loan Forgiveness Program ( PSLF ). I have been enrolled in the program and working for a qualified employer since XX/XX/XXXX. Despite submitting appropriate records including Income Based Repayment forms, annual certification forms for the PSLF program, and being enrolled in the direct debit program, XXXX XXXX XXXX still has not calculated my payments correctly. My loan was transferred to XXXX from XXXX in XX/XX/XXXX. The payments I made with XXXX are not being counted and all the qualifying payments I have made with XXXX XXXX are not being counted correctly. I have spoken with this company 9 times since the spring of XX/XX/XXXX and this situation is still not corrected. My employer has spoken with them twice and given them my correct employment start date, but my qualified payments are still not correct. Based upon my calculations, I should have made 33 qualified payments, but XXXX XXXX servicing is only crediting me with 14.
#
# Original Title:
#  Dealing with your lender or servicer
#
# ****** Machine Generated Title (Prediction) ******:
#  dealing with your lender or servicer
#
#
# ==============================================
# ============== Example # 19031 =================
#
# 2783622
# Issue Body:
#  {$1200.00} of balance from XXXX XXXX XXXX has been on my credit report for 9 years. I have tried to remove them but has not been successful.
#
# Original Title:
#  Problem with a credit reporting company's investigation into an existing problem
#
# ****** Machine Generated Title (Prediction) ******:
#  problem with a credit reporting company s investigation into an existing issue
#
#
# ==============================================
# ============== Example # 18197 =================
#
# 2851171
# Issue Body:
#  I have lived at a rental property current name ( XXXX XXXX XXXX   ) with my ex girlfriend back in 2013 XX/XX/XXXX ( we both signed the lease ) for only a month in a 6 month lease term that soon after i found out my ex girlfriend stole my check books and Debit card and had to leave the rental apartment and involved polices and paid termination fee of one month rent by myself since she was a felon and i was not aware of. I filed lawsuit meanwhile against my ex girlfriend and she founded guilty because of identity theft and forgery. After few months passed i received a letter from XXXX XXXX XXXX XXXX   that i owe XXXX  $ approximately to the apartment i lived only a month though paid them one month advanced plus deposit. This has been affecting my credit and life in general since they keep harassing me because of that even though i explained them the situation and the money i paid for additional one month rent before leaving that place. I believe i am a victim of unfair credit report by XXXX XXXX XXXX XXXX ( XXXX XXXX XXXX XXXX XXXX XXXX XXXX, GA XXXX )
#
# Original Title:
#  False statements or representation
#
# ****** Machine Generated Title (Prediction) ******:
#  attempts to collect debt not owed
#
#
# ==============================================
# ============== Example # 8619 =================
#
# 2969171
# Issue Body:
#  I have an incorrect address on my credit report : XXXX XXXX XXXX, XXXX XXXX CA XXXX that is associated with a fraudulent account from XXXX XXXX XXXX ( on behalf of XXXX ) that also appears on my credit report with a balance overdue of {$310.00}.
#
# I have contact XXXX, alerted XXXX XXXX XXXX, and filed a dispute with XXXX. I also filed a complaint with the FTC, which I have attempted several times to upload to the XXXX  website per their request, but it keeps crashing.
#
# Original Title:
#  Incorrect information on your report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on your report
#
#
# ==============================================
# ============== Example # 12932 =================
#
# 2703020
# Issue Body:
#  Chase CASE ID : XXXX My Mother had XXXX on XXXX XXXX, 2017 in XXXX, FL. I have all doctor 's note and completed Chase forms. I flew from XXXX to XXXX to take care of her. She had complications from XXXX which required her to stay in hospital until XXXX XXXX, then XXXX at home for 4-6 weeks. I stayed with her to cook, clean, make sure she took her medicine, was comfortable, was eating, went to bathroom. As a result of the XXXX complications and XXXX, I stayed in FL and was unable to take my return flight home.
#
# I asked Chase for the trip cancellation protection, but they declined it for 2 reasons. 1 ) my mom had a pre-existing condition. My mom did NOT have a XXXX XXXX. She went in for XXXX because of potential XXXX found by doctors just a few weeks prior. 2 ) XXXX refused to cancel flight instead provided flight credit expires in 1 year. But I will not be flying XXXX again because it does n't fly to destinations I frequent. I am happy to give the credit to Chase.
#
# I am disappointed that Chase trip cancellation benefit is so difficult to use. In effect, Chase is telling me that I am on my own when I helped my mother recover from XXXX.
#
# Please find attached all documents submitted to Chase : - physician 's statement signed by doctor - claim form - refund policy of XXXX - travel credit - credit card statement with XXXX charge
#
# Original Title:
#  Other features, terms, or problems
#
# ****** Machine Generated Title (Prediction) ******:
#  other features terms or problems
#
#
# ==============================================
# ============== Example # 13284 =================
#
# 2836925
# Issue Body:
#  Good morning guys, I am XXXX XXXX XXXX XXXX, I noted that my credit report through XXXX XXXX has an incorrect information.
# My mortgage account with XXXX XXXX XXXX XXXX XXXX still open and in good or excellent status.
# The only things is that the names in that account was changed from my Mother ( XXXX ) and me to my only name because of donation of my sister participation.
# The account never has being closed.
# So please correct this information that affect my credit score, with XXXX XXXX XXXX XXXX XXXX
#
# Sincerely, XXXX XXXX XXXX XXXX, XXXX
#
# Original Title:
#  Incorrect information on your report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on your report
#
#
# ==============================================
# ============== Example # 9976 =================
#
# 2431685
# Issue Body:
#  Please be advised that this is my SECOND WRITTEN REQUEST asking you to remove the unverified accounts listed below that remain on my credit report in violation of 15 U.S.C. 1681. You are required under the FCRA to have properly verified the accuracy of an account listed on my credit report. In the results of your first re-investigation, you stated in writing that you " verified '' that these items are being " reported correctly ''.
# I am certain these accounts were not verified the accounts listed below were opened on dates when I was XXXX in XXXX and not released until XX/XX/XXXX. In XXXX you are not allowed access to establish credit or access to computers to apply for credit. So stating these accounts are verified ensures me your agency is not thoroughly verifying this information. Which then is leaving false information in my credit file which is a violation. Enclosed will be proof of my XXXX during times when accounts were established.
# Where are the documents that you used to verify these accounts? What is the name of the person in your company who verified these accounts? What documents did they use to verify them? Please provide me with the name of that individual, their business address, and telephone number.
# XXXX, defines " Verify '' as, 1 ) " To prove to be true ; to confirm or establish the truth or truthfulness of ; to authenticate. '' 2 ) " to confirm or substantiate by oath or affidavit ; to swear to the truth of. '' and " Verification '' as, " Confirmation of correctness, truth or authenticity, by affidavit, oath, or deposition. Affidavit of truth of a matter stated and object of verification is to assure good faith in averments or statements of a party. '' What this means is that your company must be willing and able to produce a document in your files that proves the account ( s ) in dispute belong to me and the information being reported is accurate and you must be able to do this in a court of law if I file a lawsuit against you. Someone in your company must authenticate the documents in your files that were used to verify the disputed accounts and to do this they must have 1st hand knowledge of the alleged account ( s ) and all that has ever transpired for the alleged account ( s ), under oath and under the penalty of perjury.
# As I am sure that you are well aware, current Federal case law states that, Consumer Reporting Agencies bear grave responsibilities to ensure the accuracy of the accounts they report on and their responsibility must consist of something more than merely parroting information received from other sources. The Courts have also ordered that a " Reinvestigation '' that merely shifts the burden back to the consumer and the credit grantor can not fulfill the obligations imposed by 1681 ( a ) ( 4 ).
# You have ignored my request to provided me with the documents that you have in your files that you used to verify the disputed accounts which means that you have NOT verified or you can not verify any of these accounts and under Section 611 ( 5 ) ( A ) of the FCRA - you are required to " ... promptly DELETE all information which can not be verified. '' The law is very clear as to the Civil liability and the remedy available to me for " negligent noncompliance '' ( Section 617 ) if you fail to comply with this Federal Law. I am a litigious consumer and fully intend on pursuing litigation in this matter to enforce my rights under the FCRA. I demand the following accounts be verified or deleted immediately.
# Name of Account : Account Number : Provide Physical Proof of Verification XXXX Unverified account XXXX Unverified account XXXX
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  credit reporting company s investigation
#
#
# ==============================================
# ============== Example # 11672 =================
#
# 2826437
# Issue Body:
#  The incident occurred on XX/XX/2018.
#
# I was contacted by what was believed to be an employer, but resulted in fraudulent activity ; the bank was aware of my concerns during this interaction with the supposed employer. The bank is refusing to repair damages done to my account despite the recorded calls, text messages, emails, and documents.
#
# Before depositing a check received from this employer I verified with the bank listed on the check that the funds were available and the check was not forged, they assured me the check was real and the funds were available. I also expressed concerns with this bank about their member possibly committing fraud.
# I deposited this check into my bank account and called my bank to express concerns that the check may be bad despite what I was told by the employer 's bank, and waited until the check cleared to make any further transactions- in or out of the account.
#
# Before continuing the financial requests of the employer I once again called the bank to confirm the check was posted and good, and to clarify that I would not experience a negative balance due to the check ; the bank ensured the check was posted and it was safe to make transactions. I went forth with the requests of the employer under the impression from my bank that no backlash would happen.
#
# The first wire transfer was returned due to an error on my part and then proceeded to make another wire transfer that was approved. I called my bank before and after both wire transfers to ensure the check was still in the clear, the wire transfers were posted, and there were no concerns that would be detrimental to my credit or financial situation. I was once again reassured that everything was safe.
#
# Two days after the wire transfers were completed I checked my bank account only to see that my account was severely negative. Upon calling my bank to inquire about the status I was informed the check was returned despite what I was previously told.
# I filed a claim through my bank for fraudulent activity and contacted the employer who apologized and promised to wire the funds back into my account.
# The fraud department denied the claim expressing that it was not fraud due to my authorizing the activity. I received a receipt for the wire transfer from the employer and verified with his bank that it was completed, however, the wire transfer was never received and my bank account has been locked due to the negative funds.
#
# Because the amount is high, the bank has locked all of my bank cards, prevented access to the site to view statements and other products being used such as car insurance and rental/property insurance.
#
# Original Title:
#  Managing an account
#
# ****** Machine Generated Title (Prediction) ******:
#  managing an account
#
#
# ==============================================
# ============== Example # 20358 =================
#
# 2466419
# Issue Body:
#  I have sent several certified letters to both the collection company as well as the  XXXX  credit bureaus regarding  XXXX ,  XXXX   XXXX  and   XXXX   XXXX   accounts that I didnt authorize in my name. It has been showing up for the past few years on my report and thats not fair to me as a person who is trying to establish credit after being a victim of identity theaft for many years and i didnt know. I have a security freeze on my credit reports now. I had to work on my credit report night and day to resolve the issues that had arised. It 's  XXXX  items that needs to be removed. I am reaching out to you to see if I can get assistance from this department. Please assist me in this process. I have letters to show that ive made several contact with both creditors as well as the credit beaures. These items are seriously affecting me with obtaining credit and I NEVER DID BUSINESS WITH EITHER BUSINESS. I was n't able to attach my l ast 4 ss #  on this conplaint due to an error. Please be advised and fix this error reporting on my credit report. Thanks
#
# Original Title:
#  Incorrect information on your report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on your report
#
#
# ==============================================
# ============== Example # 15662 =================
#
# 1683066
# Issue Body:
#  Focus Receivables ManagementXXXX XXXX XXXX XXXX, GA XXXXThis company has reported to the credit agencies that I have {$38.00} in collections with XXXX XXXX from XXXX and reported it in XXXX XXXX. I 'm in the process of trying to obtain a home loan and this has negatively affected me. There is no way that this is a legitimate debt as I was not living in the United States from XXXX XXXX - XXXX XXXX, do not have XXXX XXXX nor is it even available in XXXX Idaho where I 'm currently living. They had called me several XXXX times and I informed them that this is not my debt and I do not have any account with XXXX cable. I had asked them several times to stop calling me before blocking their number. I 'm still receiving several mysterious automated calls daily.
#
# Regards, XXXX XXXX
#
# Original Title:
#  Cont'd attempts collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 21491 =================
#
# 1326184
# Issue Body:
#  Never got a formal letter of debt. No messages left for what debt it was for. Finally I spoke with someone at debt collectors. They finally sent letter for debt. I sent payment in form of XXXX XXXX for total due.Never processed payment and placed on credit report as a collection. ( Please note I never answer my phone and/or return calls unless I know who is calling, too many scams ) If they would have sent a formal letter the XXXX time this payment would have been made. As when they did, when I finally spoke with them. I made payment right away within couple days of receiving the XXXX and ONLY Letter they sent.
#
# Original Title:
#  Disclosure verification of debt
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 11293 =================
#
# 2162483
# Issue Body:
#  I have XXXX tax lien via the state of Georgia on my TransUnion credit report. I have attached documents that provide proof that the following should be deleted from my report.
#
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on credit report
#
#
# ==============================================
# ============== Example # 12591 =================
#
# 2143830
# Issue Body:
#  XXXX was deleted from my credit report on XX/XX/2016 and has been reinserted without any notification. Additionally, Equifax claims this account is still under investigation as of XX/XX/2016. I 've called Equifax to remove the item & they 're claiming they ca n't because it 's still under investigation. I 'm including the results from my original investigation which shows the account was deleted. I need this removed from my records IMMEDIATELY!!! This is a gross violation of the FCRA & I 'm entitled to {$1000.00} for this violation. Please see this matter is resolved NOW!!!
#
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on credit report
#
#
# ==============================================
# ============== Example # 4400 =================
#
# 2714138
# Issue Body:
#  I provided my XXXX XXXX information to pay for a cruise on XXXX XXXX XXXX ( " NCL '' ) My XXXX statement had an XXXX/XXXX/XXXX transaction date and a XXXX/XXXX/XXXX post date in the amounts of {$2600.00} and {$140.00}. I paid XXXX 's bill in full. Today ( XXXX/XXXX/XXXX ), XXXX week before the cruise, I XXXX told me that they never received that money from XXXX, XXXX insisted that I give them another credit card and pay the amount again or they would cancel my reservation. XXXX insists that they paid XXXX and XXXX insists that they did not get paid. I have now paid for that trip twice. That is XXXX times almost {$3000.00}. I spoke to XXXX ( XXXX XXXX ) at XXXX. XXXX was not interested in the fact that I had already paid the full amount to XXXX because they claim XXXX did not pay them. I spoke to a supervisor at XXXX named XXXX XXXX XXXX spelling may be wrong ) at XXXX in South Dakota. XXXX is a big bank for a long time that knows how to trace funds. These are two huge companies and they are leaving me out to dry, each blaming the other. How can this happen? Thank you for your attention.
# Original Title:
#  Trouble using your card
#
# ****** Machine Generated Title (Prediction) ******:
#  fees or interest
#
#
# ==============================================
# ============== Example # 2105 =================
#
# 1644856
# Issue Body:
#  I attempted to dispute some information on Equifax report. On my first attempt, I filled out the appropriate fields and verified my information. I was about to submit my request for the first dispute when the system kicked me out and said there was an error. Again, I went back to Equifax and upon correctly validating my information I was told that " The information you provided does not match our records so we are unable to process your request online. '' Equifax then asked me to fax in my dispute with a copy of my driver 's license. I tried once more, even asnwering the identity verification questions again and was given the same response. Now, when I attempt to initiate a dispute with Equifax 's credit reporting, I am no longer directed to the validation questions but am instead immediately asked to fax in my dispute as my information did not match their records. If Equifax had no record of me, how I was able to successfully log on to their site and begin the process of disputing the reporting? I would like this error to be corrected and be given access to my report so that I can dispute the inaccurate information. I even tried to access my Free Annual Report so that I could obtain a confirmation number ( much like the report numbers you get from XXXX ) and use that number to launch my dispute but was instructed to MAIL in a copy of my license and Social Security Card in order to validate my identity. It is insane that I would be expected to mail or fax any documents to Equifax after already having validated my identity and being allowed to start the dispute process.
#
# There were XXXX accounts listed that were not mine and XXXX account that could not belong to me as I have not opened any new credit accounts this year. I have attached the incorrect information as it appears on my report made available to me by XXXX. ( Even though, I am unable to dispute this information VIA XXXX as they redirect me to Equifax 's website which refuses to acknowledge that I exist. )
#
# Original Title:
#  Incorrect information on credit report
#
# ****** Machine Generated Title (Prediction) ******:
#  unable to get your credit report or credit score
#
#
# ==============================================
# ============== Example # 2024 =================
#
# 2588941
# Issue Body:
#  Between the periods of XX/XX/XXXX to XX/XX/XXXX I had purchased to vehicles and financed through Wells Fargo XXXX New and XXXX used. Through out the loan terms the subsequently on a monthly basis added and charged me for their own auto insurance even tho i had my own auto insurance policy on XXXX vehicles. This subsequently caused me be delinquent and not to be able to manage my loan payments and at different points each vehicle was repossessed even after attempts were made on my behalf to correct the problem and lower payments to no success. Eventually I was able to recover the new vehicle after paying thousands of dollars in payments and fees to be able to get it back and payed it off and finally sold it in XX/XX/XXXX. The used car tho i was not able to recover and they sold it at auction and billed me for an additional {$12000.00} which they claim was the difference and eventually i ended up paying to them to pay the supposed balance. I also had to pay taxes for the supposed losses they incurred on that vehicle to the IRS when i filled my taxes.
#
# Original Title:
#  Managing the loan or lease
#
# ****** Machine Generated Title (Prediction) ******:
#  managing the loan or lease
#
#
# ==============================================
# ============== Example # 2903 =================
#
# 1930251
# Issue Body:
#  Challenge an unfavorable section or oversight on my credit report. I am for the most part unsatisfied with CRAs reporting mistaken information, and other. XXXX archives/attach.
#
# Original Title:
#  Credit monitoring or identity protection
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on credit report
#
#
# ==============================================
# ============== Example # 15163 =================
#
# 2551431
# Issue Body:
#  We have had a checking account wi  th BB & T since 2015. We have a direct deposit monthly into the account from salary. Ever since then we have had numerous overdraft charges and fees over the last several months.
# The most recent charges are being described below because the bank has refused to provide any recompense, amendments or assistance to prevent this from happening.
# We were charged {$180.00} in overdraft last month and another {$390.00} this month. Overdrafts were charged for purchases when there was enough money to cover those items at the time. When we enquired about this, the bank said that there 's nothing they can do and that because the transaction went through at a later date there was n't enough money in the bank and we were charged overdraft. However, this was not evident in my account statement online. They said the only way for me to keep track was to write every item that I bought down and deduct it from my account.
# This bank and its employees showed no care or effort in addressing the issue or customers. We are really hoping this could be resolved and get refund back for these we were wrongfully charged for by BB & T bank.
#
# Original Title:
#  Problem caused by your funds being low
#
# ****** Machine Generated Title (Prediction) ******:
#  problem caused by your funds being low
#
#
# ==============================================
# ============== Example # 2856 =================
#
# 2993684
# Issue Body:
#  I received a mailer from open road lending  on XX/XX/2018 that says they will lower my interest rate from 6.9 % to 3.5 % on my auto loan. It says my eligibility criteria is because i have good credit. I filled out the online form on XX/XX/2018 and got a text saying I was pre approved within a few minutes.
#
# When I called they ran my credit to several lenders and told be my rate would be 7.14 % which is higher than my current rate. Now my credit will take a hit due to the inquiries and I have the same loan. Their advertisement is misleading and I feel this is a bait and switch.
#
# Original Title:
#  Getting a loan or lease
#
# ****** Machine Generated Title (Prediction) ******:
#  advertising and marketing including promotional offers
#
#
# ==============================================
# ============== Example # 12935 =================
#
# 2502851
# Issue Body:
#  TransUnion removed all of my inquiry 's and put them back without notifying me about this. I called TransUnion and was told that they did n't have a glitch   XXXX   XXXX   had a glitch. Hung up the phone called back and talked to someone else and was told they had a glitch. I was hoping TransUnion would take responsibility for there mistake but they did n't.
#
# Original Title:
#  Problem with a credit reporting company's investigation into an existing problem
#
# ****** Machine Generated Title (Prediction) ******:
#  problem with a credit reporting company s investigation into an existing issue
#
#
# ==============================================
# ============== Example # 19987 =================
#
# 3006000
# Issue Body:
#  XXXX XXXX XXXX appears on my credit file as a XXXX XXXX XXXX   XXXX  in which I did not apply for. I'm not trying to hear the XXXX about Experian owns or merge or what ever lie XXXX XXXX is running. Now its XXXX XXXX XXXX all it is a scam by Experian as well as XXXX XXXX XXXX. I did not apply or request no loan from XXXX XXXX XXXX XXXX. I'm also filing a complaint with the XXXX XXXX. I opt out with Experian in XXXX XXXX XXXX for no marketing or offers as for my opt out is violated.
# XXXX
#
# Original Title:
#  Improper use of your report
#
# ****** Machine Generated Title (Prediction) ******:
#  improper use of your report
#
#
# ==============================================
# ============== Example # 6212 =================
#
# 2595880
# Issue Body:
#  I CAN NOT GET THROUGH TO TRANSUNION IN THE UNITED STATES, EVERYTIME I CALL I 'M TOLD THAT MY CALL CAN NOT BE TRANSFERRED OR THE PHONES ARE NOT WORKING.
#
# Original Title:
#  Unable to get your credit report or credit score
#
# ****** Machine Generated Title (Prediction) ******:
#  communication tactics
#
#
# ==============================================
# ============== Example # 14182 =================
#
# 2003066
# Issue Body:
#  Upon checking my credit report, I noticed an account by the name of rise reporting to XXXX concerning me. I called and spoke with a XXXX agent with my concerns and inform them this was n't my account. The agent replied to me that the account was in good standards and as I told him, I do n't care it was n't my account and to remove it. I 've been a victim of Identity theft and I 've filed a police report case number XXXX Officer XXXX with the XXXX, Alabama XXXX Police Department. number XXXX. I 've also sent a Certified Letter with a returned receipt that I have to XXXX XXXX and Rise also the other credit reporting agent concerning this Rise Account along with a police report and Identity Theft notarized affidavit.
#
# Original Title:
#  Cont'd attempts collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  incorrect information on your report
#
#
# ==============================================
# ============== Example # 10649 =================
#
# 2359370
# Issue Body:
#  I have requested verification of debt that I do not owe and the company will not send me this information however they keep sending me letters for an account that is not mine.
#
# Original Title:
#  Disclosure verification of debt
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 171 =================
#
# 2393702
# Issue Body:
#  I do not owe this debt. I changed insurances in XX/XX/2011 and have not had XXXX since then. Also I have never owed any balances since I canceled the policy and changed to another insurance before the next month was due. This debt collection is attempting to collect illegally a debt that does not exist. Also I 've never lived in an apt as they have listed.
#
# Original Title:
#  Cont'd attempts collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
#
#
# ==============================================
# ============== Example # 6366 =================
#
# 1508746
# Issue Body:
#  Pioneer Credit Recovery is Cursing me out hanging up in my face there not willing to negotiate at All. They are not even giving Tax payers a Chance to pay back on the Loans. I 've attempted to send them payments they will not except what I can afford to send them to pay off the loan. Pioneer Credit Recovery is the worst government collection agency collecting revenue for the United States of America. They continue to attempt to Garnish funds form my Job event after I have attempted to pay them and make Payment.
#
# Original Title:
#  Taking/threatening an illegal action
#
# ****** Machine Generated Title (Prediction) ******:
#  can t repay my loan
#
#
# ==============================================
# ============== Example # 6273 =================
#
# 2989294
# Issue Body:
#  My identity was stolen in XX/XX/2015. My identity was stolen through XXXX and the amount on the account is XXXX. I am not sure when this account was created because I have had many things put into my name that are not mine. However, I estimate the account to be created around XX/XX/2015. I have contacted XXXX many times about this account not being mine and this is not my debt to be paid and they still put it on my credit score and ruin my credit. There has already been a police report file and I have all of the documents stating that this account is not mine and this is not my debt to be owed.
#
# Original Title:
#  Attempts to collect debt not owed
#
# ****** Machine Generated Title (Prediction) ******:
#  cont d attempts collect debt not owed
